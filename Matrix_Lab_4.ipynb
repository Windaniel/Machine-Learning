# %%
# Introduction to Matrix creation of a nexted list 
houses= [
    [1500, 3],
    [1200, 2],
    [1800, 4]
] 
print('the matrix is:')
for i in houses:
    print(i)
# Out:
# the matrix
# [1500, 3]
# [1200, 2]
# [1800, 4]
